# %%
from pystac_client import Client
import json
import glob
import requests
import boto3
import base64
import time

# %%
discover_items_file_paths = glob.glob("../ingestion-data/discovery-items/*.json")
# discover_items_ids = [i.split("/")[-1].split(".")[0] for i in discover_items_file_paths]

# %%
API = "https://staging-stac.delta-backend.com/"
client = Client.open(API)
staging_collections = [i.id for i in list(client.get_collections())]

# %% [markdown]
# ## Create transfer configs

# %%
for filename in discover_items_file_paths:
    with open(filename, "r") as f:
        dataset = json.load(f)
        if not isinstance(dataset, list):
            dataset = [dataset]

        id = dataset[0]["collection"]
        transfer_config = []
        for i in dataset:
            if (
                i["collection"] in staging_collections
            ):  # only create config for collections in staging
                config = dict()
                config["origin_bucket"] = i.get("bucket", "")
                config["origin_prefix"] = i.get("prefix", "")
                config["target_bucket"] = "veda-data-store"
                config["collection"] = i.get("collection")

                if "assets" in i:  # conditional for multi asset discovery items
                    for k, v in i["assets"].items():
                        config["filename_regex"] = v.get("regex")
                        transfer_config.append(config.copy())
                else:
                    config["filename_regex"] = i.get("filename_regex", "")
                    transfer_config.append(config)

            with open(
                f"../ingestion-data/transfer-config/{id}.json", "w", encoding="utf-8"
            ) as file:
                print(f"writing file: ingestion_data/transfer-config/{id}")
                json.dump(transfer_config, file, ensure_ascii=False, indent=4)
# Out:
# writing file: ingestion_data/transfer-config/campfire-lst-night-diff
# writing file: ingestion_data/transfer-config/OMI_trno2-COG
# writing file: ingestion_data/transfer-config/lis-global-da-tws
# writing file: ingestion_data/transfer-config/conus-reach
# writing file: ingestion_data/transfer-config/ndvi_diff_Ian_2022-09-30_2022-09-05
# writing file: ingestion_data/transfer-config/entropy_difference_2022-09-05_2022-09-30
# writing file: ingestion_data/transfer-config/snow-projections-median-585
# writing file: ingestion_data/transfer-config/geoglam
# writing file: ingestion_data/transfer-config/OMSO2PCA-COG
# writing file: ingestion_data/transfer-config/lis-global-da-tws-trend
# writing file: ingestion_data/transfer-config/lis-global-da-tws-trend
# writing file: ingestion_data/transfer-config/lis-global-da-tws-trend
# writing file: ingestion_data/transfer-config/grdi-v1-raster
# writing file: ingestion_data/transfer-config/grdi-v1-raster
# writing file: ingestion_data/transfer-config/grdi-v1-raster
# writing file: ingestion_data/transfer-config/grdi-v1-raster
# writing file: ingestion_data/transfer-config/grdi-v1-raster
# writing file: ingestion_data/transfer-config/grdi-v1-raster
# writing file: ingestion_data/transfer-config/grdi-v1-raster
# writing file: ingestion_data/transfer-config/grdi-v1-raster
# writing file: ingestion_data/transfer-config/lis-tws-nonstationarity-index
# writing file: ingestion_data/transfer-config/modis-albedo-wsa-diff-2015-2022
# writing file: ingestion_data/transfer-config/ceos-co2-flux-budgets-mean
# writing file: ingestion_data/transfer-config/snow-projections-median-245
# writing file: ingestion_data/transfer-config/ecco-surface-height-change
# writing file: ingestion_data/transfer-config/hls-l30-002-ej-reprocessed
# writing file: ingestion_data/transfer-config/houston-aod
# writing file: ingestion_data/transfer-config/ls8-covid-19-example-data
# writing file: ingestion_data/transfer-config/IS2SITMOGR4-cog
# writing file: ingestion_data/transfer-config/hls-bais2-v2
# writing file: ingestion_data/transfer-config/recovery-proxy-maps-covid-19
# writing file: ingestion_data/transfer-config/lis-global-da-swe
# writing file: ingestion_data/transfer-config/campfire-ndvi-diff
# writing file: ingestion_data/transfer-config/lis-global-da-gpp-trend
# writing file: ingestion_data/transfer-config/nightlights-500m-daily
# writing file: ingestion_data/transfer-config/nightlights-500m-daily
# writing file: ingestion_data/transfer-config/nightlights-500m-daily
# writing file: ingestion_data/transfer-config/nightlights-500m-daily
# writing file: ingestion_data/transfer-config/nightlights-500m-daily
# writing file: ingestion_data/transfer-config/nightlights-500m-daily
# writing file: ingestion_data/transfer-config/nightlights-500m-daily
# writing file: ingestion_data/transfer-config/barc-thomasfire
# writing file: ingestion_data/transfer-config/cygnss-watermask-ucar
# writing file: ingestion_data/transfer-config/nightlights-hd-1band
# writing file: ingestion_data/transfer-config/nightlights-hd-1band
# writing file: ingestion_data/transfer-config/modis-lst-night-diff-2015-2022
# writing file: ingestion_data/transfer-config/lis-global-da-gpp
# writing file: ingestion_data/transfer-config/lis-global-da-evap
# writing file: ingestion_data/transfer-config/houston-lst-day
# writing file: ingestion_data/transfer-config/landsat-c2l2-sr-antarctic-glaciers-pine-island
# writing file: ingestion_data/transfer-config/cygnss-watermask-ucberkeley
# writing file: ingestion_data/transfer-config/lis-global-da-qs
# writing file: ingestion_data/transfer-config/lis-global-da-qsb
# writing file: ingestion_data/transfer-config/blue-tarp-planetscope
# writing file: ingestion_data/transfer-config/landsat-c2l2-sr-lakes-aral-sea
# writing file: ingestion_data/transfer-config/damage_probability_2022-10-03
# writing file: ingestion_data/transfer-config/caldor-fire-burn-severity
# writing file: ingestion_data/transfer-config/houston-lst-diff
# writing file: ingestion_data/transfer-config/co2-mean
# writing file: ingestion_data/transfer-config/co2-mean
# writing file: ingestion_data/transfer-config/co2-mean
# writing file: ingestion_data/transfer-config/co2-mean
# writing file: ingestion_data/transfer-config/co2-mean
# writing file: ingestion_data/transfer-config/co2-mean
# writing file: ingestion_data/transfer-config/co2-mean
# writing file: ingestion_data/transfer-config/co2-mean
# writing file: ingestion_data/transfer-config/nceo_africa_2017
# writing file: ingestion_data/transfer-config/HLSL30
# writing file: ingestion_data/transfer-config/disturbance-probability-percentile
# writing file: ingestion_data/transfer-config/landsat-c2l2-sr-lakes-tonle-sap
# writing file: ingestion_data/transfer-config/disalexi-etsuppression
# writing file: ingestion_data/transfer-config/houston-aod-diff
# writing file: ingestion_data/transfer-config/nightlights-hd-3bands
# writing file: ingestion_data/transfer-config/HLSS30
# writing file: ingestion_data/transfer-config/nightlights-hd-monthly
# writing file: ingestion_data/transfer-config/nightlights-hd-monthly
# writing file: ingestion_data/transfer-config/nightlights-hd-monthly
# writing file: ingestion_data/transfer-config/nightlights-hd-monthly
# writing file: ingestion_data/transfer-config/nightlights-hd-monthly
# writing file: ingestion_data/transfer-config/nightlights-hd-monthly
# writing file: ingestion_data/transfer-config/nightlights-hd-monthly
# writing file: ingestion_data/transfer-config/nightlights-hd-monthly
# writing file: ingestion_data/transfer-config/nightlights-hd-monthly
# writing file: ingestion_data/transfer-config/nightlights-hd-monthly
# writing file: ingestion_data/transfer-config/nightlights-hd-monthly
# writing file: ingestion_data/transfer-config/nightlights-hd-monthly
# writing file: ingestion_data/transfer-config/nightlights-hd-monthly
# writing file: ingestion_data/transfer-config/nightlights-hd-monthly
# writing file: ingestion_data/transfer-config/nightlights-hd-monthly
# writing file: ingestion_data/transfer-config/nightlights-hd-monthly
# writing file: ingestion_data/transfer-config/nightlights-hd-monthly
# writing file: ingestion_data/transfer-config/nightlights-hd-monthly
# writing file: ingestion_data/transfer-config/nightlights-hd-monthly
# writing file: ingestion_data/transfer-config/nightlights-hd-monthly
# writing file: ingestion_data/transfer-config/nightlights-hd-monthly
# writing file: ingestion_data/transfer-config/nightlights-hd-monthly
# writing file: ingestion_data/transfer-config/nightlights-hd-monthly
# writing file: ingestion_data/transfer-config/nightlights-hd-monthly
# writing file: ingestion_data/transfer-config/nightlights-hd-monthly
# writing file: ingestion_data/transfer-config/nightlights-hd-monthly
# writing file: ingestion_data/transfer-config/slowdown-proxy-covid-19-changing-landscapes
# writing file: ingestion_data/transfer-config/HLSS30
# writing file: ingestion_data/transfer-config/ceos-co2-flux-budgets
# writing file: ingestion_data/transfer-config/houston-landcover
# writing file: ingestion_data/transfer-config/frp-max-thomasfire
# writing file: ingestion_data/transfer-config/landsat-c2l2-sr-lakes-lake-balaton
# writing file: ingestion_data/transfer-config/modis-fire-anomalies-diff-covid-19-changing-landscape
# writing file: ingestion_data/transfer-config/landsat-nighttime-thermal
# writing file: ingestion_data/transfer-config/lis-global-da-totalprecip
# writing file: ingestion_data/transfer-config/hls-bais2
# writing file: ingestion_data/transfer-config/lis-tws-anomaly
# writing file: ingestion_data/transfer-config/lis-tws-anomaly
# writing file: ingestion_data/transfer-config/lis-tws-anomaly
# writing file: ingestion_data/transfer-config/lis-tws-anomaly
# writing file: ingestion_data/transfer-config/lis-tws-anomaly
# writing file: ingestion_data/transfer-config/lis-tws-anomaly
# writing file: ingestion_data/transfer-config/lis-tws-anomaly
# writing file: ingestion_data/transfer-config/lis-tws-anomaly
# writing file: ingestion_data/transfer-config/lis-tws-anomaly
# writing file: ingestion_data/transfer-config/lis-tws-anomaly
# writing file: ingestion_data/transfer-config/lis-tws-anomaly
# writing file: ingestion_data/transfer-config/lis-tws-anomaly
# writing file: ingestion_data/transfer-config/lis-tws-anomaly
# writing file: ingestion_data/transfer-config/lis-tws-anomaly
# writing file: ingestion_data/transfer-config/lis-tws-anomaly
# writing file: ingestion_data/transfer-config/lis-tws-anomaly
# writing file: ingestion_data/transfer-config/lis-tws-anomaly
# writing file: ingestion_data/transfer-config/lis-tws-anomaly
# writing file: ingestion_data/transfer-config/lis-tws-anomaly
# writing file: ingestion_data/transfer-config/lis-tws-anomaly
# writing file: ingestion_data/transfer-config/lis-tws-anomaly
# writing file: ingestion_data/transfer-config/lis-tws-anomaly
# writing file: ingestion_data/transfer-config/CMIP585-winter-median-ta
# writing file: ingestion_data/transfer-config/CMIP585-winter-median-ta
# writing file: ingestion_data/transfer-config/CMIP585-winter-median-ta
# writing file: ingestion_data/transfer-config/CMIP585-winter-median-ta
# writing file: ingestion_data/transfer-config/snow-projections-diff-245
# writing file: ingestion_data/transfer-config/campfire-nlcd
# writing file: ingestion_data/transfer-config/EPA-monthly-emissions_1A_Combustion_Stationary
# writing file: ingestion_data/transfer-config/EPA-monthly-emissions_1A_Combustion_Stationary
# writing file: ingestion_data/transfer-config/EPA-monthly-emissions_1A_Combustion_Stationary
# writing file: ingestion_data/transfer-config/EPA-monthly-emissions_1A_Combustion_Stationary
# writing file: ingestion_data/transfer-config/EPA-monthly-emissions_1A_Combustion_Stationary
# writing file: ingestion_data/transfer-config/EPA-monthly-emissions_1A_Combustion_Stationary
# writing file: ingestion_data/transfer-config/togo-agriculture-covid-19
# writing file: ingestion_data/transfer-config/snow-projections-diff-585
# writing file: ingestion_data/transfer-config/houston-ndvi
# writing file: ingestion_data/transfer-config/CMIP245-winter-median-ta
# writing file: ingestion_data/transfer-config/CMIP245-winter-median-ta
# writing file: ingestion_data/transfer-config/CMIP245-winter-median-ta
# writing file: ingestion_data/transfer-config/CMIP245-winter-median-ta
# writing file: ingestion_data/transfer-config/campfire-albedo-wsa-diff
# writing file: ingestion_data/transfer-config/houston-lst-night
# writing file: ingestion_data/transfer-config/co2-diff
# writing file: ingestion_data/transfer-config/co2-diff
# writing file: ingestion_data/transfer-config/co2-diff
# writing file: ingestion_data/transfer-config/co2-diff
# writing file: ingestion_data/transfer-config/co2-diff
# writing file: ingestion_data/transfer-config/co2-diff
# writing file: ingestion_data/transfer-config/co2-diff
# writing file: ingestion_data/transfer-config/co2-diff
# writing file: ingestion_data/transfer-config/blue-tarp-detection
# writing file: ingestion_data/transfer-config/lis-etsuppression
# writing file: ingestion_data/transfer-config/nightlights-hd-monthly
# writing file: ingestion_data/transfer-config/caldor-fire-behavior
# writing file: ingestion_data/transfer-config/lis-tvegsuppression
# writing file: ingestion_data/transfer-config/modis-annual-lai-2003-2020
# writing file: ingestion_data/transfer-config/modis-annual-lai-2003-2020
# writing file: ingestion_data/transfer-config/hls-s30-002-ej-reprocessed
# writing file: ingestion_data/transfer-config/lis-global-da-streamflow
# writing file: ingestion_data/transfer-config/pzd-anomaly-covid-19
# writing file: ingestion_data/transfer-config/HLSL30
# writing file: ingestion_data/transfer-config/houston-urbanization
# writing file: ingestion_data/transfer-config/modis-lst-day-diff-2015-2022
# writing file: ingestion_data/transfer-config/hls-ndvi
# writing file: ingestion_data/transfer-config/modis_diff
# writing file: ingestion_data/transfer-config/modis_diff
# writing file: ingestion_data/transfer-config/landsat-c2l2-sr-lakes-vanern
# writing file: ingestion_data/transfer-config/lis-global-da-gws
# writing file: ingestion_data/transfer-config/no2-monthly-diff
# writing file: ingestion_data/transfer-config/CMIP245-winter-median-pr
# writing file: ingestion_data/transfer-config/CMIP245-winter-median-pr
# writing file: ingestion_data/transfer-config/CMIP245-winter-median-pr
# writing file: ingestion_data/transfer-config/CMIP245-winter-median-pr
# writing file: ingestion_data/transfer-config/landsat-c2l2-sr-antarctic-glaciers-thwaites
# writing file: ingestion_data/transfer-config/bangladesh-landcover-2001-2020
# writing file: ingestion_data/transfer-config/bangladesh-landcover-2001-2020
# writing file: ingestion_data/transfer-config/mtbs-burn-severity
# writing file: ingestion_data/transfer-config/mtbs-burn-severity
# writing file: ingestion_data/transfer-config/mtbs-burn-severity
# writing file: ingestion_data/transfer-config/mtbs-burn-severity
# writing file: ingestion_data/transfer-config/mtbs-burn-severity
# writing file: ingestion_data/transfer-config/facebook_population_density
# writing file: ingestion_data/transfer-config/landsat-c2l2-sr-lakes-lake-biwa
# writing file: ingestion_data/transfer-config/MO_NPP_npp_vgpm
# writing file: ingestion_data/transfer-config/social-vulnerability-index-household
# writing file: ingestion_data/transfer-config/social-vulnerability-index-household
# writing file: ingestion_data/transfer-config/social-vulnerability-index-household
# writing file: ingestion_data/transfer-config/social-vulnerability-index-household
# writing file: ingestion_data/transfer-config/social-vulnerability-index-household
# writing file: ingestion_data/transfer-config/social-vulnerability-index-household
# writing file: ingestion_data/transfer-config/social-vulnerability-index-household
# writing file: ingestion_data/transfer-config/social-vulnerability-index-household
# writing file: ingestion_data/transfer-config/social-vulnerability-index-household
# writing file: ingestion_data/transfer-config/social-vulnerability-index-household
# writing file: ingestion_data/transfer-config/fldas-soil-moisture-anomalies
# writing file: ingestion_data/transfer-config/modis-ndvi-diff-2015-2022
# writing file: ingestion_data/transfer-config/no2-monthly
# writing file: ingestion_data/transfer-config/EPA-daily-emissions_5_Forest_Fires
# writing file: ingestion_data/transfer-config/lis-tws-trend
# writing file: ingestion_data/transfer-config/sport-lis-vsm0_100cm-percentile
# writing file: ingestion_data/transfer-config/EPA-annual-emissions_1A_Combustion_Mobile
# writing file: ingestion_data/transfer-config/EPA-annual-emissions_1A_Combustion_Mobile
# writing file: ingestion_data/transfer-config/EPA-annual-emissions_1A_Combustion_Mobile
# writing file: ingestion_data/transfer-config/EPA-annual-emissions_1A_Combustion_Mobile
# writing file: ingestion_data/transfer-config/EPA-annual-emissions_1A_Combustion_Mobile
# writing file: ingestion_data/transfer-config/EPA-annual-emissions_1A_Combustion_Mobile
# writing file: ingestion_data/transfer-config/EPA-annual-emissions_1A_Combustion_Mobile
# writing file: ingestion_data/transfer-config/EPA-annual-emissions_1A_Combustion_Mobile
# writing file: ingestion_data/transfer-config/EPA-annual-emissions_1A_Combustion_Mobile
# writing file: ingestion_data/transfer-config/EPA-annual-emissions_1A_Combustion_Mobile
# writing file: ingestion_data/transfer-config/EPA-annual-emissions_1A_Combustion_Mobile
# writing file: ingestion_data/transfer-config/EPA-annual-emissions_1A_Combustion_Mobile
# writing file: ingestion_data/transfer-config/EPA-annual-emissions_1A_Combustion_Mobile
# writing file: ingestion_data/transfer-config/EPA-annual-emissions_1A_Combustion_Mobile
# writing file: ingestion_data/transfer-config/EPA-annual-emissions_1A_Combustion_Mobile
# writing file: ingestion_data/transfer-config/EPA-annual-emissions_1A_Combustion_Mobile
# writing file: ingestion_data/transfer-config/EPA-annual-emissions_1A_Combustion_Mobile
# writing file: ingestion_data/transfer-config/EPA-annual-emissions_1A_Combustion_Mobile
# writing file: ingestion_data/transfer-config/EPA-annual-emissions_1A_Combustion_Mobile
# writing file: ingestion_data/transfer-config/EPA-annual-emissions_1A_Combustion_Mobile
# writing file: ingestion_data/transfer-config/EPA-annual-emissions_1A_Combustion_Mobile
# writing file: ingestion_data/transfer-config/EPA-annual-emissions_1A_Combustion_Mobile
# writing file: ingestion_data/transfer-config/hls-swir-falsecolor-composite
# writing file: ingestion_data/transfer-config/combined_CMIP6_daily_GISS-E2-1-G_tas_kerchunk_DEMO
# writing file: ingestion_data/transfer-config/campfire-lst-day-diff
# writing file: ingestion_data/transfer-config/CMIP585-winter-median-pr
# writing file: ingestion_data/transfer-config/CMIP585-winter-median-pr
# writing file: ingestion_data/transfer-config/CMIP585-winter-median-pr
# writing file: ingestion_data/transfer-config/CMIP585-winter-median-pr

# %% [markdown]
# ## Run DAG in Airflow

# %%
mwaa_name = "veda-pipeline-dev-mwaa"
dry_run = False

# %%
def get_mwaa_cli_token(mwaa_name, profile):
    session = boto3.session.Session(profile_name=profile)
    airflow_client = session.client("mwaa")
    return airflow_client.create_cli_token(Name=mwaa_name)

# %%
transfer_items_file_paths = glob.glob("../ingestion-data/transfer-config/*.json")

for transfer_item_file in transfer_items_file_paths:
    print(f"Transferring using config: {transfer_item_file}")
    with open(transfer_item_file, "r") as f:
        transfer_configs = json.load(f)
        for transfer_config in transfer_configs:
            mwaa_cli_token = get_mwaa_cli_token(
                mwaa_name, "veda"
            )  # get token in inside loop or else token will expire in long lists
            mwaa_auth_token = "Bearer " + mwaa_cli_token["CliToken"]
            if (
                transfer_config["origin_prefix"] == ""
                or transfer_config["filename_regex"] == ""
            ):
                print(
                    f"{transfer_item_file} transfer skipped, no origin prefix or regex"
                )
                pass
            else:
                if not dry_run:
                    raw_data = f"dags trigger veda_transfer --conf '{json.dumps(transfer_config)}'"
                    mwaa_response = requests.post(
                        f"https://{mwaa_cli_token['WebServerHostname']}/aws_mwaa/cli",
                        headers={
                            "Authorization": mwaa_auth_token,
                            "Content-Type": "application/json",
                        },
                        data=raw_data,
                    )
                    try:
                        mwaa_std_err_message = base64.b64decode(
                            mwaa_response.json()["stderr"]
                        ).decode("utf8")
                        mwaa_std_out_message = base64.b64decode(
                            mwaa_response.json()["stdout"]
                        ).decode("utf8")
                        print(mwaa_response.status_code)
                        print(f"stderr: {mwaa_std_err_message}")
                        print(f"stdout: {mwaa_std_out_message}")
                    except:
                        print(mwaa_response)
# Out:
# Transferring using config: ../ingestion-data/transfer-config/campfire-lst-night-diff.json
# 200
# stderr:
# stdout: Created <DagRun veda_transfer @ 2024-03-15T21:09:11+00:00: manual__2024-03-15T21:09:11+00:00, state:queued, queued_at: 2024-03-15 21:09:11.246305+00:00. externally triggered: True>
#
# Transferring using config: ../ingestion-data/transfer-config/OMI_trno2-COG.json
# 200
# stderr:
# stdout: Created <DagRun veda_transfer @ 2024-03-15T21:09:14+00:00: manual__2024-03-15T21:09:14+00:00, state:queued, queued_at: 2024-03-15 21:09:14.333873+00:00. externally triggered: True>
#
# Transferring using config: ../ingestion-data/transfer-config/lis-global-da-tws.json
# 200
# stderr:
# stdout: Created <DagRun veda_transfer @ 2024-03-15T21:09:17+00:00: manual__2024-03-15T21:09:17+00:00, state:queued, queued_at: 2024-03-15 21:09:17.497107+00:00. externally triggered: True>
#
# Transferring using config: ../ingestion-data/transfer-config/HLSS30.json
# Transferring using config: ../ingestion-data/transfer-config/conus-reach.json
# 200
# stderr:
# stdout: Created <DagRun veda_transfer @ 2024-03-15T21:09:20+00:00: manual__2024-03-15T21:09:20+00:00, state:queued, queued_at: 2024-03-15 21:09:20.675166+00:00. externally triggered: True>
#
# Transferring using config: ../ingestion-data/transfer-config/ndvi_diff_Ian_2022-09-30_2022-09-05.json
# Transferring using config: ../ingestion-data/transfer-config/entropy_difference_2022-09-05_2022-09-30.json
# Transferring using config: ../ingestion-data/transfer-config/snow-projections-median-585.json
# 200
# stderr:
# stdout: Created <DagRun veda_transfer @ 2024-03-15T21:09:23+00:00: manual__2024-03-15T21:09:23+00:00, state:queued, queued_at: 2024-03-15 21:09:23.977996+00:00. externally triggered: True>
#
# Transferring using config: ../ingestion-data/transfer-config/geoglam.json
# 200
# stderr:
# stdout: Created <DagRun veda_transfer @ 2024-03-15T21:09:30+00:00: manual__2024-03-15T21:09:30+00:00, state:queued, queued_at: 2024-03-15 21:09:30.198569+00:00. externally triggered: True>
#
# Transferring using config: ../ingestion-data/transfer-config/OMSO2PCA-COG.json
# 200
# stderr:
# stdout: Created <DagRun veda_transfer @ 2024-03-15T21:09:33+00:00: manual__2024-03-15T21:09:33+00:00, state:queued, queued_at: 2024-03-15 21:09:33.982006+00:00. externally triggered: True>
#
# Transferring using config: ../ingestion-data/transfer-config/lis-global-da-tws-trend.json
# 200
# stderr:
# stdout: Created <DagRun veda_transfer @ 2024-03-15T21:09:36+00:00: manual__2024-03-15T21:09:36+00:00, state:queued, queued_at: 2024-03-15 21:09:36.752003+00:00. externally triggered: True>
#
# 200
# stderr:
# stdout: Created <DagRun veda_transfer @ 2024-03-15T21:09:39+00:00: manual__2024-03-15T21:09:39+00:00, state:queued, queued_at: 2024-03-15 21:09:39.527077+00:00. externally triggered: True>
#
# 200
# stderr:
# stdout: Created <DagRun veda_transfer @ 2024-03-15T21:09:42+00:00: manual__2024-03-15T21:09:42+00:00, state:queued, queued_at: 2024-03-15 21:09:42.323687+00:00. externally triggered: True>
#
# Transferring using config: ../ingestion-data/transfer-config/facebook_population_density.json
# 200
# stderr:
# stdout: Created <DagRun veda_transfer @ 2024-03-15T21:09:45+00:00: manual__2024-03-15T21:09:45+00:00, state:queued, queued_at: 2024-03-15 21:09:45.363059+00:00. externally triggered: True>
#
# Transferring using config: ../ingestion-data/transfer-config/lis-tws-nonstationarity-index.json
# 200
# stderr:
# stdout: Created <DagRun veda_transfer @ 2024-03-15T21:09:48+00:00: manual__2024-03-15T21:09:48+00:00, state:queued, queued_at: 2024-03-15 21:09:48.317617+00:00. externally triggered: True>
#
# Transferring using config: ../ingestion-data/transfer-config/modis-albedo-wsa-diff-2015-2022.json
# 200
# stderr:
# stdout: Created <DagRun veda_transfer @ 2024-03-15T21:09:51+00:00: manual__2024-03-15T21:09:51+00:00, state:queued, queued_at: 2024-03-15 21:09:51.294268+00:00. externally triggered: True>
#
# Transferring using config: ../ingestion-data/transfer-config/ceos-co2-flux-budgets-mean.json
# 200
# stderr:
# stdout: Created <DagRun veda_transfer @ 2024-03-15T21:09:54+00:00: manual__2024-03-15T21:09:54+00:00, state:queued, queued_at: 2024-03-15 21:09:54.343312+00:00. externally triggered: True>
#
# 200
# stderr:
# stdout: Created <DagRun veda_transfer @ 2024-03-15T21:10:00+00:00: manual__2024-03-15T21:10:00+00:00, state:queued, queued_at: 2024-03-15 21:10:00.198835+00:00. externally triggered: True>
#
# 200
# stderr:
# stdout: Created <DagRun veda_transfer @ 2024-03-15T21:10:03+00:00: manual__2024-03-15T21:10:03+00:00, state:queued, queued_at: 2024-03-15 21:10:03.207247+00:00. externally triggered: True>
#
# 200
# stderr:
# stdout: Created <DagRun veda_transfer @ 2024-03-15T21:10:05+00:00: manual__2024-03-15T21:10:05+00:00, state:queued, queued_at: 2024-03-15 21:10:05.964643+00:00. externally triggered: True>
#
# 200
# stderr:
# stdout: Created <DagRun veda_transfer @ 2024-03-15T21:10